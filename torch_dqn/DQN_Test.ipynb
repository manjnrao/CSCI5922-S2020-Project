# %%
import gym
import dqn

# %%
env = gym.make("CartPole-v0")
agent = dqn.Agent("CartPoleSolver", env, target_score=195.0)

# %%
agent.learn_env(1000)
agent.display_scores()
# Out:
# 00:00:06 - Episode 100	Average Score: 27.43
# 00:00:21 - Episode 200	Average Score: 62.43
# 00:01:03 - Episode 300	Average Score: 183.64
# 00:01:44 - Episode 400	Average Score: 173.80
# 00:02:20 - Episode 500	Average Score: 158.08
# 00:02:47 - Episode 600	Average Score: 118.92
# 00:03:29 - Episode 693	Average Score: 195.19
# 00:03:29 - Environment solved in 593 episodes!	Average Score: 195.19

# %%
agent.play()
env.close()
